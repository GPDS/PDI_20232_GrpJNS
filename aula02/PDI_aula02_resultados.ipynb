# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2
import os

# %%
dummy = np.arange(1, 16)

# %%
# PSNR Redução

cairn = [21.61, 26.33, 20.29, 22.68, 28.78, 19.86, 19.83, 26.67, 18.40, 19.98, 26.69, 18.91, 29.06, 32.53, 35.20]
runner = [22.09, 28.82, 21.13, 23.05, 31.34, 20.72, 20.02, 29.13, 19.14, 20.25, 29.22, 19.51, 29.01, 32.65, 36.09]
shutters = [16.76, 18.81, 14.34, 19.52, 20.88, 13.00, 17.49, 19.34, 12.78, 17.66, 19.16, 13.90, 19.36, 23.40, 27.04]
swan = [28.49, 29.60, 26.43, 31.43, 32.07, 25.98, 29.60, 30.07, 25.85, 29.76, 30.08, 26.07, 31.10, 34.10, 37.26]

plt.figure(figsize=(6, 4), layout='constrained')
plt.plot(dummy, cairn, label='cairn')
plt.plot(dummy, runner, label='runner')
plt.plot(dummy, shutters, label='shutters')
plt.plot(dummy, swan, label='swan')
plt.xticks(np.arange(1, 16, 1))
plt.xlabel('Filtros')
plt.ylabel('PSNR (dB)')
plt.grid(True)
plt.legend();

# %%
# SSIM Redução

cairn = [0.86, 0.88, 0.84, 0.90, 0.91, 0.82, 0.85, 0.86, 0.78, 0.85, 0.85, 0.78, 0.94, 0.96, 0.97]
runner = [0.85, 0.87, 0.81, 0.90, 0.90, 0.80, 0.86, 0.87, 0.79, 0.86, 0.86, 0.80, 0.86, 0.91, 0.94]
shutters = [0.48, 0.54, 0.44, 0.64, 0.65, 0.37, 0.51, 0.52, 0.28, 0.48, 0.47, 0.30, 0.65, 0.82, 0.90]
swan = [0.90, 0.91, 0.84, 0.93, 0.94, 0.84, 0.89, 0.90, 0.83, 0.89, 0.89, 0.82, 0.95, 0.97, 0.98]

plt.figure(figsize=(6, 4), layout='constrained')
plt.plot(dummy, cairn, label='cairn')
plt.plot(dummy, runner, label='runner')
plt.plot(dummy, shutters, label='shutters')
plt.plot(dummy, swan, label='swan')
plt.xticks(np.arange(1, 16, 1))
plt.xlabel('Filtros')
plt.ylabel('SSIM')
plt.grid(True)
plt.legend();

# %%
# PSNR Expansão

cairn = [24.32,28.93,23.81,25.07,29.90,24.89,22.51,28.46,22.07,22.58,28.26,21.51,29.15,30.44,29.15]
runner = [24.32,28.89,24.19,24.78,29.31,24.68,22.40,28.62,22.25,22.52,28.51,21.93,28.97,29.54,28.97]
shutters = [17.97,19.20,17.58,19.11,19.72,18.94,17.74,18.86,17.23,17.90,18.66,16.08,19.39,20.07,19.39]
swan = [29.99,30.91,29.25,31.42,31.61,31.14,30.36,30.50,29.16,30.43,30.34,27.97,31.14,32.10,31.14]

plt.figure(figsize=(6, 4), layout='constrained')
plt.plot(dummy, cairn, label='cairn')
plt.plot(dummy, runner, label='runner')
plt.plot(dummy, shutters, label='shutters')
plt.plot(dummy, swan, label='swan')
plt.xticks(np.arange(1, 16, 1))
plt.xlabel('Filtros')
plt.ylabel('PSNR (dB)')
plt.grid(True)
plt.legend();

# %%
# SSIM Expansão

cairn = [0.90,0.92,0.89,0.92,0.92,0.91,0.89,0.90,0.88,0.88,0.89,0.85,0.92,0.93,0.92]
runner = [0.82,0.83,0.82,0.83,0.83,0.83,0.81,0.81,0.81,0.81,0.80,0.80,0.83,0.84,0.83]
shutters = [0.48,0.51,0.47,0.52,0.51,0.54,0.43,0.43,0.46,0.40,0.38,0.39,0.54,0.57,0.54]
swan = [0.92,0.93,0.91,0.93,0.93,0.93,0.92,0.92,0.91,0.91,0.91,0.89,0.93,0.94,0.93]

plt.figure(figsize=(6, 4), layout='constrained')
plt.plot(dummy, cairn, label='cairn')
plt.plot(dummy, runner, label='runner')
plt.plot(dummy, shutters, label='shutters')
plt.plot(dummy, swan, label='swan')
plt.xticks(np.arange(1, 16, 1))
plt.xlabel('Filtros')
plt.ylabel('SSIM')
plt.grid(True)
plt.legend();

# %%
imagens_originais_dir = '/content/drive/MyDrive/PDI/projeto01/imagens/originais/'
imagens_originais_reduzidas_dir = '/content/drive/MyDrive/PDI/projeto01/imagens/reduzidas_fator_2/'
resultados_dir = '/content/drive/MyDrive/PDI/projeto01/resultados/'
imagens_resultantes_downsampling_dir = '/content/drive/MyDrive/PDI/projeto01/imagens/resultantes_downsampling/'
imagens_resultantes_upsampling_dir = '/content/drive/MyDrive/PDI/projeto01/imagens/resultantes_upsampling/'

# %%
for arquivo in os.listdir(imagens_originais_dir):
  print(arquivo)
# Out:
# shutters-8198905.jpg
# swan-8174925.jpg
# cairn-8195026.jpg
# runner-7876675.jpg

# %%
img1 = cv2.imread(os.path.join(imagens_originais_dir, 'cairn-8195026.jpg'), cv2.IMREAD_GRAYSCALE)
img2 = cv2.imread(os.path.join(imagens_originais_dir, 'runner-7876675.jpg'), cv2.IMREAD_GRAYSCALE)
img3 = cv2.imread(os.path.join(imagens_originais_dir, 'shutters-8198905.jpg'), cv2.IMREAD_GRAYSCALE)
img4 = cv2.imread(os.path.join(imagens_originais_dir, 'swan-8174925.jpg'), cv2.IMREAD_GRAYSCALE)
fig, axs = plt.subplots(2, 2, figsize=(12, 8))

# plt.figure(figsize=(100, 200))

axs[0,0].set_title('cairn')
axs[0,0].imshow(cv2.cvtColor(img1, cv2.COLOR_BGR2RGB))
# axs[0,0].axis('off')

axs[0,1].set_title('runner')
axs[0,1].imshow(cv2.cvtColor(img2, cv2.COLOR_BGR2RGB))
# axs[0,1].axis('off')

axs[1,0].set_title('shutters')
axs[1,0].imshow(cv2.cvtColor(img3, cv2.COLOR_BGR2RGB))
# axs[1,0].axis('off')

axs[1,1].set_title('swan')
axs[1,1].imshow(cv2.cvtColor(img4, cv2.COLOR_BGR2RGB))
# axs[1,1].axis('off')
plt.show()

# %%
img1 = cv2.imread('/content/drive/MyDrive/PDI/projeto01/imagens/reduzidas_fator_2/swan-8174925.jpg', cv2.IMREAD_GRAYSCALE)
img2 = cv2.imread('/content/drive/MyDrive/PDI/projeto01/imagens/resultantes_downsampling/swan-8174925.jpg_media_3x3.jpg', cv2.IMREAD_GRAYSCALE)
img3 = cv2.imread('/content/drive/MyDrive/PDI/projeto01/imagens/resultantes_downsampling/swan-8174925.jpg_moda_4x4.jpg', cv2.IMREAD_GRAYSCALE)
img4 = cv2.imread('/content/drive/MyDrive/PDI/projeto01/imagens/resultantes_downsampling/swan-8174925.jpg_cv2INTER_AREA.jpg', cv2.IMREAD_GRAYSCALE)
fig, axs = plt.subplots(2, 2, figsize=(12, 8))

# plt.figure(figsize=(100, 200))

axs[0,0].set_title('Referência')
axs[0,0].imshow(img1, cmap='gray')
# axs[0,0].axis('off')

axs[0,1].set_title('Filtro Média 3x3')
axs[0,1].imshow(img2, cmap='gray')
# axs[0,1].axis('off')

axs[1,0].set_title('Filtro Moda 4x4')
axs[1,0].imshow(img3, cmap='gray')
# axs[1,0].axis('off')

axs[1,1].set_title('Filtro cv2.INTER_AREA')
axs[1,1].imshow(img4, cmap='gray')
# axs[1,1].axis('off')
plt.show()

# %%
img1 = cv2.imread('/content/drive/MyDrive/PDI/projeto01/imagens/reduzidas_fator_2/shutters-8198905.jpg', cv2.IMREAD_GRAYSCALE)
img2 = cv2.imread('/content/drive/MyDrive/PDI/projeto01/imagens/resultantes_downsampling/shutters-8198905.jpg_media_3x3.jpg', cv2.IMREAD_GRAYSCALE)
img3 = cv2.imread('/content/drive/MyDrive/PDI/projeto01/imagens/resultantes_downsampling/shutters-8198905.jpg_moda_4x4.jpg', cv2.IMREAD_GRAYSCALE)
img4 = cv2.imread('/content/drive/MyDrive/PDI/projeto01/imagens/resultantes_downsampling/shutters-8198905.jpg_cv2INTER_AREA.jpg', cv2.IMREAD_GRAYSCALE)
fig, axs = plt.subplots(2, 2, figsize=(12, 8))

# plt.figure(figsize=(100, 200))

axs[0,0].set_title('Referência')
axs[0,0].imshow(img1, cmap='gray')
# axs[0,0].axis('off')

axs[0,1].set_title('Filtro Média 3x3')
axs[0,1].imshow(img2, cmap='gray')
# axs[0,1].axis('off')

axs[1,0].set_title('Filtro Moda 4x4')
axs[1,0].imshow(img3, cmap='gray')
# axs[1,0].axis('off')

axs[1,1].set_title('Filtro cv2.INTER_AREA')
axs[1,1].imshow(img4, cmap='gray')
# axs[1,1].axis('off')
plt.show()

# %%
img1 = cv2.imread('/content/drive/MyDrive/PDI/projeto01/imagens/originais/swan-8174925.jpg', cv2.IMREAD_GRAYSCALE)
img2 = cv2.imread('/content/drive/MyDrive/PDI/projeto01/imagens/resultantes_upsampling/swan-8174925.jpg_media_3x3.jpg', cv2.IMREAD_GRAYSCALE)
img3 = cv2.imread('/content/drive/MyDrive/PDI/projeto01/imagens/resultantes_upsampling/swan-8174925.jpg_moda_5x5.jpg', cv2.IMREAD_GRAYSCALE)
img4 = cv2.imread('/content/drive/MyDrive/PDI/projeto01/imagens/resultantes_upsampling/swan-8174925.jpg_cv2INTER_CUBIC.jpg', cv2.IMREAD_GRAYSCALE)
fig, axs = plt.subplots(2, 2, figsize=(12, 8))

# plt.figure(figsize=(100, 200))

axs[0,0].set_title('Referência')
axs[0,0].imshow(img1, cmap='gray')
# axs[0,0].axis('off')

axs[0,1].set_title('Filtro Média 3x3')
axs[0,1].imshow(img2, cmap='gray')
# axs[0,1].axis('off')

axs[1,0].set_title('Filtro Moda 5x5')
axs[1,0].imshow(img3, cmap='gray')
# axs[1,0].axis('off')

axs[1,1].set_title('Filtro cv2.INTER_CUBIC')
axs[1,1].imshow(img4, cmap='gray')
# axs[1,1].axis('off')
plt.show()

# %%
img1 = cv2.imread('/content/drive/MyDrive/PDI/projeto01/imagens/originais/shutters-8198905.jpg', cv2.IMREAD_GRAYSCALE)
img2 = cv2.imread('/content/drive/MyDrive/PDI/projeto01/imagens/resultantes_upsampling/shutters-8198905.jpg_media_3x3.jpg', cv2.IMREAD_GRAYSCALE)
img3 = cv2.imread('/content/drive/MyDrive/PDI/projeto01/imagens/resultantes_upsampling/shutters-8198905.jpg_moda_5x5.jpg', cv2.IMREAD_GRAYSCALE)
img4 = cv2.imread('/content/drive/MyDrive/PDI/projeto01/imagens/resultantes_upsampling/shutters-8198905.jpg_cv2INTER_CUBIC.jpg', cv2.IMREAD_GRAYSCALE)
fig, axs = plt.subplots(2, 2, figsize=(12, 8))

# plt.figure(figsize=(100, 200))

axs[0,0].set_title('Referência')
axs[0,0].imshow(img1, cmap='gray')
# axs[0,0].axis('off')

axs[0,1].set_title('Filtro Média 3x3')
axs[0,1].imshow(img2, cmap='gray')
# axs[0,1].axis('off')

axs[1,0].set_title('Filtro Moda 5x5')
axs[1,0].imshow(img3, cmap='gray')
# axs[1,0].axis('off')

axs[1,1].set_title('Filtro cv2.INTER_CUBIC')
axs[1,1].imshow(img4, cmap='gray')
# axs[1,1].axis('off')
plt.show()
